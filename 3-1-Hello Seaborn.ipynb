# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b><h2>Seaborn</h2></b>
#     <ul>
#     <br><li> Matplotlib üzerine inşa edilmiş, göze daha hoş gelen görselleştirmeler yapılabilen bir kütüphanedir.
#     </ul>
#     <img src="https://seaborn.pydata.org/_images/seaborn-lineplot-6.png" width=400 />
# </div>
#
# #### Bu bölümde işlenecek konular
#
# 1. [Lineplot](#bir)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('./Data/data-for-datavis/fifa.csv',index_col="Date",parse_dates=True)

# %%
data.head(3)
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0

# %% [markdown]
# <div id="bir"  style="color:blue;"> 1. Lineplot Oluşturma</div>
# <ul>
# <li> Verileri birbirine bağlı olacak şekilde çizgi frekansı çıkaran modüldür
# <li> plt.figure ile çıktı boyutunu düzenleyebiliriz
# </ul>

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data=data)
